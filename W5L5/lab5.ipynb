# %%
import numpy as np
import matplotlib.pyplot as plt
import mkl

mkl.set_num_threads(2)
np.random.seed(1234)

# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'
plt.rcParams["figure.figsize"] = [16, 9]

# %% [markdown]
# ### Handy utility functions

# %%
def append_ones(matrix, axis=1):
    return np.concatenate((matrix, np.ones((matrix.shape[0], 1), dtype=np.float32)), axis=axis)

def zeros(*dims):
    return np.zeros(shape=tuple(dims), dtype=np.float32)

def ones(*dims):
    return np.ones(shape=tuple(dims), dtype=np.float32)

def rand(*dims):
    return np.random.rand(*dims).astype(np.float32)

def chunks(seq, size):
    return (seq[pos:pos + size] for pos in range(0, len(seq), size))

def tiles(examples):
    rows_count = examples.shape[0]
    cols_count = examples.shape[1]
    tile_height = examples.shape[2]
    tile_width = examples.shape[3]
    
    space_between_tiles = 2
    img_matrix = np.empty(shape=(rows_count * (tile_height + space_between_tiles) - space_between_tiles,  
                                 cols_count * (tile_width + space_between_tiles) - space_between_tiles))
    img_matrix.fill(np.nan)

    for r in range(rows_count):
        for c in range(cols_count):
            x_0 = r * (tile_height + space_between_tiles)
            y_0 = c * (tile_width + space_between_tiles)
            ex_min = np.min(examples[r, c])
            ex_max = np.max(examples[r, c])
            img_matrix[x_0:x_0 + tile_height, y_0:y_0 + tile_width] = (examples[r, c] - ex_min) / (ex_max - ex_min)
    
    plt.matshow(img_matrix, cmap='gray', interpolation='none')
    plt.axis('off')
    plt.show()

# %% [markdown]
# # MNIST dataset

# %%
from mnists import MNIST
mnist = MNIST()
digits = np.reshape(mnist.train_images()[:12*24], newshape=(12, 24, 28, 28))
tiles(digits)
# Out:
# Downloading https://storage.googleapis.com/cvdf-datasets/mnist/train-images-idx3-ubyte.gz to /tmp/mnists/MNIST/train-images-idx3-ubyte.gz
# Downloading https://storage.googleapis.com/cvdf-datasets/mnist/train-labels-idx1-ubyte.gz to /tmp/mnists/MNIST/train-labels-idx1-ubyte.gz
# Downloading https://storage.googleapis.com/cvdf-datasets/mnist/t10k-images-idx3-ubyte.gz to /tmp/mnists/MNIST/t10k-images-idx3-ubyte.gz
# Downloading https://storage.googleapis.com/cvdf-datasets/mnist/t10k-labels-idx1-ubyte.gz to /tmp/mnists/MNIST/t10k-labels-idx1-ubyte.gz

# %% [markdown]
# # Restricted Boltzmann Machine & Contrastive Divergence algorithm

# %%
def sigmoid(matrix):
    return 1.0 / (1.0 + np.exp(-matrix))

class Rbm:
    def __init__(self, visible_size, hidden_size, learning_rate, momentum):
        self.visible_size = visible_size
        self.hidden_size = hidden_size
        self.learning_rate = learning_rate
        self.momentum = momentum
        
        self.reset()
    
    def reset(self):
        self.W = np.random.normal(scale=0.01, size=(self.visible_size+1, self.hidden_size+1)).astype(np.float32)
        self.W[:, -1] = 0.0
        self.W[-1, :] = 0.0
        self.M = zeros(self.visible_size+1, self.hidden_size+1)

# %%
def reconstuction_error(rbm, minibatch):
    observations_count = minibatch.shape[0]
    visible = zeros(observations_count, rbm.visible_size)
    hidden = append_ones(zeros(observations_count, rbm.hidden_size))

    hidden[:, :-1] = sigmoid(minibatch @ rbm.W[:, :-1]) > rand(hidden.shape[0], hidden.shape[1] - 1)
    visible = sigmoid(hidden @ rbm.W[:-1, :].T)
    error = np.sum((minibatch[:, :-1] - visible) ** 2) / observations_count

    return error

# %%
def train_epoch(rbm, dataset, batch_size):
    batches_limit = dataset.shape[0] / batch_size
    for batch_idx, batch in enumerate(chunks(dataset, batch_size)):
        cdk(rbm, batch)
        if batch_idx % round(batches_limit / 50) == 0: print("#", end="")

def run_training(rbm, dataset, monitoring_set, batch_size, epochs_count):
    for epoch in range(epochs_count):
        print("Epoch {}:".format(epoch),  end="\t")
        
        if epoch == 5:
            rbm.momentum = 0.8

        start_time = time.time()
        train_epoch(rbm, dataset, batch_size)
        elapsed = time.time() - start_time
        
        error = reconstuction_error(rbm, monitoring_set)
        print("\telapsed: {0:>2.2f}s, reconstruction error: {1:>2.2f}".format(elapsed, error))

    print("Training finished!")

# %%
def draw_filters(rbm):
    filters = np.reshape(np.transpose(rbm.W)[:-1, :-1], newshape=(8, -1, 28, 28))
    tiles(filters)

# %% [markdown]
# # 1. RBM Training with momentum

# %%
def cdk(rbm, minibatch, k=1):
    observations_count = minibatch.shape[0];

    positive_visible = minibatch;
    negative_visible = append_ones(zeros(observations_count, rbm.visible_size))

    positive_hidden = append_ones(zeros(observations_count, rbm.hidden_size))
    negative_hidden = append_ones(zeros(observations_count, rbm.hidden_size))

    positive_hidden[:, :-1] = sigmoid(positive_visible @ rbm.W[:, :-1]) 
    positive_gradient = positive_visible.T @ positive_hidden

    
    #h_0
    negative_hidden[:, :-1] = positive_hidden[:, :-1] > rand(observations_count, rbm.hidden_size)

    #v_1
    negative_visible[:, :-1] = sigmoid(negative_hidden @ rbm.W[:-1, :].T) > rand(observations_count, rbm.visible_size)

    for _ in range(k-1):
    # Propagacja wstecz do h1
        negative_hidden[:, :-1] = sigmoid(negative_visible @ rbm.W[:, :-1]) > rand(observations_count, rbm.hidden_size)
    # Rekonstrukcja danych (v1)
        negative_visible[:, :-1] = sigmoid(negative_hidden @ rbm.W[:-1, :].T) > rand(observations_count, rbm.visible_size)

    negative_hidden[:, :-1] = sigmoid(negative_visible @ rbm.W[:, :-1])
    # 4. Gradient negatywny
    negative_gradient = negative_visible.T @ negative_hidden

    # 5. Aktualizacja wag przy wykożystaniu momentum
    rbm.M = rbm.momentum * rbm.M + rbm.learning_rate * ((positive_gradient - negative_gradient) / observations_count).astype(np.float32)
    rbm.W += rbm.M

# %%
import time

DATASET_SIZE = 20000 # 60000 for whole dataset
DIGIT_SIZE = 28

VISIBLE_LAYER_SIZE = DIGIT_SIZE*DIGIT_SIZE
HIDDEN_LAYER_SIZE = 128

mnist_train = mnist.train_images().astype(np.float32) / 255.0
np.random.shuffle(mnist_train)
dataset = np.reshape(mnist_train[:DATASET_SIZE], newshape=(DATASET_SIZE, DIGIT_SIZE*DIGIT_SIZE))
dataset = append_ones(dataset)

monitoring_indeces = np.random.choice(DATASET_SIZE, 256, replace=False)
monitoring_set = dataset[monitoring_indeces]

# %%
BATCH_SIZE = 128
EPOCHS_COUNT = 50

LEARNING_RATE = 0.1
MOMENTUM = 0.5

rbm = Rbm(VISIBLE_LAYER_SIZE, HIDDEN_LAYER_SIZE, LEARNING_RATE, MOMENTUM)
draw_filters(rbm)

run_training(rbm, dataset, monitoring_set, BATCH_SIZE, EPOCHS_COUNT)

draw_filters(rbm)
# Out:
# Epoch 0:	#####################################################	elapsed: 7.50s, reconstruction error: 26.46
# Epoch 1:	#####################################################	elapsed: 6.30s, reconstruction error: 21.39
# Epoch 2:	#####################################################	elapsed: 8.50s, reconstruction error: 18.77
# Epoch 3:	#####################################################	elapsed: 5.99s, reconstruction error: 17.27
# Epoch 4:	#####################################################	elapsed: 7.41s, reconstruction error: 16.23
# Epoch 5:	#####################################################	elapsed: 7.28s, reconstruction error: 15.07
# Epoch 6:	#####################################################	elapsed: 9.19s, reconstruction error: 13.99
# Epoch 7:	#####################################################	elapsed: 6.78s, reconstruction error: 13.33
# Epoch 8:	#####################################################	elapsed: 7.10s, reconstruction error: 12.93
# Epoch 9:	#####################################################	elapsed: 9.19s, reconstruction error: 12.61
# Epoch 10:	#####################################################	elapsed: 7.60s, reconstruction error: 12.20
# Epoch 11:	#####################################################	elapsed: 9.28s, reconstruction error: 11.98
# Epoch 12:	#####################################################	elapsed: 8.30s, reconstruction error: 11.76
# Epoch 13:	#####################################################	elapsed: 6.61s, reconstruction error: 11.69
# Epoch 14:	#####################################################	elapsed: 7.72s, reconstruction error: 11.64
# Epoch 15:	#####################################################	elapsed: 7.98s, reconstruction error: 11.26
# Epoch 16:	#####################################################	elapsed: 9.30s, reconstruction error: 11.20
# Epoch 17:	#####################################################	elapsed: 10.98s, reconstruction error: 11.27
# Epoch 18:	#####################################################	elapsed: 14.80s, reconstruction error: 11.15
# Epoch 19:	#####################################################	elapsed: 14.61s, reconstruction error: 11.06
# Epoch 20:	#####################################################	elapsed: 11.41s, reconstruction error: 11.05
# Epoch 21:	#####################################################	elapsed: 11.69s, reconstruction error: 11.03
# Epoch 22:	#####################################################	elapsed: 11.91s, reconstruction error: 10.82
# Epoch 23:	#####################################################	elapsed: 12.10s, reconstruction error: 10.97
# Epoch 24:	#####################################################	elapsed: 14.40s, reconstruction error: 10.86
# Epoch 25:	#####################################################	elapsed: 9.22s, reconstruction error: 10.90
# Epoch 26:	#####################################################	elapsed: 11.90s, reconstruction error: 10.72
# Epoch 27:	#####################################################	elapsed: 13.70s, reconstruction error: 10.66
# Epoch 28:	#####################################################	elapsed: 8.09s, reconstruction error: 10.66
# Epoch 29:	#####################################################	elapsed: 6.70s, reconstruction error: 10.46
# Epoch 30:	#####################################################	elapsed: 7.40s, reconstruction error: 10.44
# Epoch 31:	#####################################################	elapsed: 8.60s, reconstruction error: 10.42
# Epoch 32:	#####################################################	elapsed: 9.80s, reconstruction error: 10.48
# Epoch 33:	###############################################
# /tmp/ipykernel_646810/4013762205.py:2: RuntimeWarning: overflow encountered in exp
#   return 1.0 / (1.0 + np.exp(-matrix))
# ######	elapsed: 8.00s, reconstruction error: 10.64
# Epoch 34:	#####################################################	elapsed: 8.31s, reconstruction error: 10.45
# Epoch 35:	#####################################################	elapsed: 7.40s, reconstruction error: 10.44
# Epoch 36:	#####################################################	elapsed: 6.82s, reconstruction error: 10.33
# Epoch 37:	#####################################################	elapsed: 8.32s, reconstruction error: 10.41
# Epoch 38:	#####################################################	elapsed: 10.50s, reconstruction error: 10.34
# Epoch 39:	#####################################################	elapsed: 14.69s, reconstruction error: 10.34
# Epoch 40:	#####################################################	elapsed: 13.19s, reconstruction error: 10.40
# Epoch 41:	#####################################################	elapsed: 14.40s, reconstruction error: 10.37
# Epoch 42:	#####################################################	elapsed: 13.71s, reconstruction error: 10.18
# Epoch 43:	#####################################################	elapsed: 9.31s, reconstruction error: 10.27
# Epoch 44:	#####################################################	elapsed: 5.18s, reconstruction error: 10.36
# Epoch 45:	#####################################################	elapsed: 5.90s, reconstruction error: 10.25
# Epoch 46:	#####################################################	elapsed: 8.49s, reconstruction error: 10.15
# Epoch 47:	#####################################################	elapsed: 9.50s, reconstruction error: 10.29
# Epoch 48:	#####################################################	elapsed: 7.10s, reconstruction error: 10.15
# Epoch 49:	#####################################################	elapsed: 7.69s, reconstruction error: 10.07
# Training finished!

# %% [markdown]
# # 2. DBN Training

# %%
def propagate_up(dbn, layers_count, visible):
    for i in range(layers_count):
        visible = append_ones(sigmoid(visible @ dbn[i].W[:, :-1]))
    return visible

def propagate_down(dbn, layers_count, hidden):
    for i in reversed(range(layers_count)):
        hidden = append_ones(sigmoid(hidden @ np.transpose(dbn[i].W[:-1, :])))
    return hidden

# %% [markdown]
# ### DBN reconstruction error

# %%
def dbn_reconstuction_error(dbn, layers_count, minibatch):
    propagated = propagate_up(dbn, layers_count, minibatch)
    return reconstuction_error(dbn[layers_count], propagated)

# %% [markdown]
# ### Sampling in Deep Belief Networks

# %%
def sample_rbm(rbm, minibatch, steps):
    observations_count = minibatch.shape[0]

    visible = minibatch
    hidden = append_ones(zeros(observations_count, rbm.hidden_size))
    
    for cd_i in range(steps):
        hidden[:, :-1] = sigmoid(visible @ rbm.W[:, :-1])
        hidden[:, :-1] = (hidden[:, :-1] > rand(observations_count, rbm.hidden_size)).astype(np.float32)
    
        visible[:, :-1] = sigmoid(hidden @ np.transpose(rbm.W[:-1, :]))
        if cd_i < (steps - 1):
            visible[:, :-1] = (visible[:, :-1] > rand(observations_count, rbm.visible_size)).astype(np.float32)

    return visible

# %%
def sample_dbn(dbn, layer_idx, minibatch, steps):
    sample = propagate_up(dbn, layer_idx, minibatch)
    sample = sample_rbm(dbn[layer_idx], sample, steps)
    sample = propagate_down(dbn, layer_idx, sample)
    
    return sample

# %%
def draw_layer_samples(dbn, layer_idx, minibatch, steps=200):
    samples = sample_dbn(dbn, layer_idx, minibatch, steps)
    tiles(np.reshape(samples[:, :-1], newshape=(-1, 16, 28, 28)))

# %% [markdown]
# ### Greedy layer-wise training

# %%
def train_dbn(dbn, layer_idx, dataset, batch_size):
    dataset = propagate_up(dbn, layer_idx, dataset)
    
    batches_limit = dataset.shape[0] / batch_size
    for batch_idx, batch in enumerate(chunks(dataset, batch_size)):
        cdk(dbn[layer_idx], batch)
        if batch_idx % round(batches_limit / 50) == 0: print("#", end="")

# %%
BATCH_SIZE = 128
EPOCHS_COUNT = 50

LEARNING_RATE = 0.1
MOMENTUM = 0.5

DBN_HIDDEN_LAYER_SIZE = 200
dbn = [
    Rbm(VISIBLE_LAYER_SIZE, DBN_HIDDEN_LAYER_SIZE, LEARNING_RATE, MOMENTUM),
    Rbm(DBN_HIDDEN_LAYER_SIZE, DBN_HIDDEN_LAYER_SIZE, LEARNING_RATE, MOMENTUM),
    Rbm(DBN_HIDDEN_LAYER_SIZE, DBN_HIDDEN_LAYER_SIZE, LEARNING_RATE, MOMENTUM)
]

for layer_idx in range(len(dbn)):
    print("\nLearning layer {}".format(layer_idx))

    for epoch in range(EPOCHS_COUNT):
        print("Epoch {}:".format(epoch),  end="\t")

        if epoch == 5:
            dbn[layer_idx].momentum = 0.8
        
        start_time = time.time()
        train_dbn(dbn, layer_idx, dataset, BATCH_SIZE)
        elapsed = time.time() - start_time
        
        error = dbn_reconstuction_error(dbn, layer_idx, monitoring_set)
        print("\telapsed: {0:>2.2f}s, reconstruction error: {1:>2.2f}".format(elapsed, error))
    
print("Training finished!")
# Out:
# Learning layer 0
# Epoch 0:	#####################################################	elapsed: 8.62s, reconstruction error: 24.78
# Epoch 1:	#####################################################	elapsed: 7.90s, reconstruction error: 19.41
# Epoch 2:	#####################################################	elapsed: 8.59s, reconstruction error: 16.81
# Epoch 3:	#####################################################	elapsed: 9.89s, reconstruction error: 15.26
# Epoch 4:	#####################################################	elapsed: 8.90s, reconstruction error: 14.04
# Epoch 5:	#####################################################	elapsed: 7.59s, reconstruction error: 13.04
# Epoch 6:	#####################################################	elapsed: 7.18s, reconstruction error: 12.11
# Epoch 7:	#####################################################	elapsed: 7.49s, reconstruction error: 11.51
# Epoch 8:	#####################################################	elapsed: 7.81s, reconstruction error: 10.93
# Epoch 9:	#####################################################	elapsed: 8.70s, reconstruction error: 10.50
# Epoch 10:	#####################################################	elapsed: 7.49s, reconstruction error: 10.27
# Epoch 11:	#####################################################	elapsed: 8.29s, reconstruction error: 9.92
# Epoch 12:	#####################################################	elapsed: 7.80s, reconstruction error: 9.88
# Epoch 13:	#####################################################	elapsed: 8.50s, reconstruction error: 9.82
# Epoch 14:	#####################################################	elapsed: 8.53s, reconstruction error: 9.57
# Epoch 15:	#####################################################	elapsed: 8.09s, reconstruction error: 9.54
# Epoch 16:	#####################################################	elapsed: 7.97s, reconstruction error: 9.48
# Epoch 17:	#####################################################	elapsed: 9.11s, reconstruction error: 9.37
# Epoch 18:	#####################################################	elapsed: 8.80s, reconstruction error: 9.07
# Epoch 19:	#####################################################	elapsed: 8.20s, reconstruction error: 9.25
# Epoch 20:	#####################################################	elapsed: 8.30s, reconstruction error: 9.25
# Epoch 21:	#####################################################	elapsed: 9.60s, reconstruction error: 9.13
# Epoch 22:	#####################################################	elapsed: 10.78s, reconstruction error: 9.01
# Epoch 23:	#####################################################	elapsed: 9.62s, reconstruction error: 9.05
# Epoch 24:	#####################################################	elapsed: 8.53s, reconstruction error: 9.01
# Epoch 25:	#####################################################	elapsed: 8.57s, reconstruction error: 8.79
# Epoch 26:	#####################################################	elapsed: 9.48s, reconstruction error: 8.96
# Epoch 27:	#####################################################	elapsed: 8.02s, reconstruction error: 8.95
# Epoch 28:	#####################################################	elapsed: 8.03s, reconstruction error: 8.80
# Epoch 29:	#####################################################	elapsed: 8.91s, reconstruction error: 8.72
# Epoch 30:	#####################################################	elapsed: 8.20s, reconstruction error: 8.79
# Epoch 31:	#####################################################	elapsed: 8.79s, reconstruction error: 8.73
# Epoch 32:	#####################################################	elapsed: 7.29s, reconstruction error: 8.91
# Epoch 33:	#####################################################	elapsed: 7.30s, reconstruction error: 8.97
# Epoch 34:	#####################################################	elapsed: 10.28s, reconstruction error: 8.55
# Epoch 35:	#####################################################	elapsed: 7.11s, reconstruction error: 8.63
# Epoch 36:	#####################################################	elapsed: 7.78s, reconstruction error: 8.63
# Epoch 37:	#####################################################	elapsed: 8.42s, reconstruction error: 8.57
# Epoch 38:	#####################################################	elapsed: 7.53s, reconstruction error: 8.62
# Epoch 39:	#####################################################	elapsed: 10.20s, reconstruction error: 8.61
# Epoch 40:	#####################################################	elapsed: 9.39s, reconstruction error: 8.54
# Epoch 41:	#####################################################	elapsed: 11.30s, reconstruction error: 8.61
# Epoch 42:	#####################################################	elapsed: 10.09s, reconstruction error: 8.51
# Epoch 43:	#####################################################	elapsed: 11.40s, reconstruction error: 8.49
# Epoch 44:	#####################################################	elapsed: 11.98s, reconstruction error: 8.46
# Epoch 45:	#####################################################	elapsed: 8.91s, reconstruction error: 8.51
# Epoch 46:	#####################################################	elapsed: 9.60s, reconstruction error: 8.33
# Epoch 47:	#####################################################	elapsed: 11.71s, reconstruction error: 8.46
# Epoch 48:	#####################################################	elapsed: 10.80s, reconstruction error: 8.36
# Epoch 49:	#####################################################	elapsed: 9.49s, reconstruction error: 8.41
#
# Learning layer 1
# Epoch 0:	#####################################################	elapsed: 4.11s, reconstruction error: 14.45
# Epoch 1:	#####################################################	elapsed: 3.90s, reconstruction error: 10.93
# Epoch 2:	#####################################################	elapsed: 3.09s, reconstruction error: 9.22
# Epoch 3:	#####################################################	elapsed: 3.10s, reconstruction error: 8.17
# Epoch 4:	#####################################################	elapsed: 5.00s, reconstruction error: 7.61
# Epoch 5:	#####################################################	elapsed: 5.50s, reconstruction error: 6.89
# Epoch 6:	#####################################################	elapsed: 3.29s, reconstruction error: 6.39
# Epoch 7:	#####################################################	elapsed: 4.11s, reconstruction error: 6.02
# Epoch 8:	#####################################################	elapsed: 3.68s, reconstruction error: 5.79
# Epoch 9:	#####################################################	elapsed: 5.48s, reconstruction error: 5.46
# Epoch 10:	#####################################################	elapsed: 4.19s, reconstruction error: 5.38
# Epoch 11:	#####################################################	elapsed: 5.40s, reconstruction error: 5.10
# Epoch 12:	#####################################################	elapsed: 4.71s, reconstruction error: 5.00
# Epoch 13:	#####################################################	elapsed: 4.51s, reconstruction error: 4.95
# Epoch 14:	#####################################################	elapsed: 4.19s, reconstruction error: 4.91
# Epoch 15:	#####################################################	elapsed: 4.49s, reconstruction error: 4.81
# Epoch 16:	#####################################################	elapsed: 4.48s, reconstruction error: 4.73
# Epoch 17:	#####################################################	elapsed: 3.42s, reconstruction error: 4.74
# Epoch 18:	#####################################################	elapsed: 3.82s, reconstruction error: 4.67
# Epoch 19:	#####################################################	elapsed: 4.69s, reconstruction error: 4.57
# Epoch 20:	#####################################################	elapsed: 5.48s, reconstruction error: 4.59
# Epoch 21:	#####################################################	elapsed: 2.50s, reconstruction error: 4.50
# Epoch 22:	#####################################################	elapsed: 4.28s, reconstruction error: 4.58
# Epoch 23:	#####################################################	elapsed: 3.99s, reconstruction error: 4.42
# Epoch 24:	#####################################################	elapsed: 4.61s, reconstruction error: 4.52
# Epoch 25:	#####################################################	elapsed: 5.49s, reconstruction error: 4.45
# Epoch 26:	#####################################################	elapsed: 6.20s, reconstruction error: 4.34
# Epoch 27:	#####################################################	elapsed: 4.70s, reconstruction error: 4.30
# Epoch 28:	#####################################################	elapsed: 3.99s, reconstruction error: 4.31
# Epoch 29:	#####################################################	elapsed: 3.80s, reconstruction error: 4.34
# Epoch 30:	#####################################################	elapsed: 4.40s, reconstruction error: 4.24
# Epoch 31:	#####################################################	elapsed: 4.19s, reconstruction error: 4.32
# Epoch 32:	#####################################################	elapsed: 4.69s, reconstruction error: 4.21
# Epoch 33:	#####################################################	elapsed: 5.99s, reconstruction error: 4.37
# Epoch 34:	#####################################################	elapsed: 3.99s, reconstruction error: 4.22
# Epoch 35:	#####################################################	elapsed: 3.92s, reconstruction error: 4.20
# Epoch 36:	#####################################################	elapsed: 3.10s, reconstruction error: 4.24
# Epoch 37:	#####################################################	elapsed: 3.80s, reconstruction error: 4.18
# Epoch 38:	#####################################################	elapsed: 4.30s, reconstruction error: 4.17
# Epoch 39:	#####################################################	elapsed: 6.31s, reconstruction error: 4.18
# Epoch 40:	#####################################################	elapsed: 5.91s, reconstruction error: 4.29
# Epoch 41:	#####################################################	elapsed: 5.29s, reconstruction error: 4.15
# Epoch 42:	#####################################################	elapsed: 4.50s, reconstruction error: 4.18
# Epoch 43:	#####################################################	elapsed: 5.40s, reconstruction error: 4.09
# Epoch 44:	#####################################################	elapsed: 4.31s, reconstruction error: 4.21
# Epoch 45:	#####################################################	elapsed: 4.70s, reconstruction error: 4.19
# Epoch 46:	#####################################################	elapsed: 4.89s, reconstruction error: 4.08
# Epoch 47:	#####################################################	elapsed: 5.50s, reconstruction error: 4.10
# Epoch 48:	#####################################################	elapsed: 5.20s, reconstruction error: 4.04
# Epoch 49:	#####################################################	elapsed: 4.40s, reconstruction error: 4.19
#
# Learning layer 2
# Epoch 0:	#####################################################	elapsed: 5.51s, reconstruction error: 10.41
# Epoch 1:	#####################################################	elapsed: 4.79s, reconstruction error: 7.61
# Epoch 2:	#####################################################	elapsed: 4.60s, reconstruction error: 6.29
# Epoch 3:	#####################################################	elapsed: 5.10s, reconstruction error: 5.49
# Epoch 4:	#####################################################	elapsed: 4.39s, reconstruction error: 5.19
# Epoch 5:	#####################################################	elapsed: 4.70s, reconstruction error: 4.52
# Epoch 6:	#####################################################	elapsed: 3.89s, reconstruction error: 4.22
# Epoch 7:	#####################################################	elapsed: 5.90s, reconstruction error: 4.02
# Epoch 8:	#####################################################	elapsed: 7.29s, reconstruction error: 3.82
# Epoch 9:	#####################################################	elapsed: 4.51s, reconstruction error: 3.74
# Epoch 10:	#####################################################	elapsed: 4.00s, reconstruction error: 3.54
# Epoch 11:	#####################################################	elapsed: 4.30s, reconstruction error: 3.53
# Epoch 12:	#####################################################	elapsed: 3.30s, reconstruction error: 3.48
# Epoch 13:	#####################################################	elapsed: 4.80s, reconstruction error: 3.36
# Epoch 14:	#####################################################	elapsed: 3.80s, reconstruction error: 3.29
# Epoch 15:	#####################################################	elapsed: 4.40s, reconstruction error: 3.27
# Epoch 16:	#####################################################	elapsed: 4.99s, reconstruction error: 3.24
# Epoch 17:	#####################################################	elapsed: 3.90s, reconstruction error: 3.14
# Epoch 18:	#####################################################	elapsed: 5.01s, reconstruction error: 3.24
# Epoch 19:	#####################################################	elapsed: 5.20s, reconstruction error: 3.18
# Epoch 20:	#####################################################	elapsed: 5.20s, reconstruction error: 3.14
# Epoch 21:	#####################################################	elapsed: 4.51s, reconstruction error: 3.06
# Epoch 22:	#####################################################	elapsed: 6.29s, reconstruction error: 3.14
# Epoch 23:	#####################################################	elapsed: 4.40s, reconstruction error: 3.09
# Epoch 24:	#####################################################	elapsed: 3.80s, reconstruction error: 3.08
# Epoch 25:	#####################################################	elapsed: 5.09s, reconstruction error: 3.04
# Epoch 26:	#####################################################	elapsed: 4.60s, reconstruction error: 3.11
# Epoch 27:	#####################################################	elapsed: 2.79s, reconstruction error: 2.92
# Epoch 28:	#####################################################	elapsed: 4.51s, reconstruction error: 3.10
# Epoch 29:	#####################################################	elapsed: 5.49s, reconstruction error: 2.99
# Epoch 30:	#####################################################	elapsed: 4.10s, reconstruction error: 2.98
# Epoch 31:	#####################################################	elapsed: 5.60s, reconstruction error: 2.99
# Epoch 32:	#####################################################	elapsed: 6.19s, reconstruction error: 2.98
# Epoch 33:	#####################################################	elapsed: 6.01s, reconstruction error: 3.02
# Epoch 34:	#####################################################	elapsed: 5.11s, reconstruction error: 2.95
# Epoch 35:	#####################################################	elapsed: 5.48s, reconstruction error: 2.93
# Epoch 36:	#####################################################	elapsed: 5.59s, reconstruction error: 2.89
# Epoch 37:	#####################################################	elapsed: 5.40s, reconstruction error: 2.97
# Epoch 38:	#####################################################	elapsed: 5.53s, reconstruction error: 2.90
# Epoch 39:	#####################################################	elapsed: 2.41s, reconstruction error: 2.94
# Epoch 40:	#####################################################	elapsed: 6.59s, reconstruction error: 2.97
# Epoch 41:	#####################################################	elapsed: 5.41s, reconstruction error: 3.01
# Epoch 42:	#####################################################	elapsed: 5.58s, reconstruction error: 2.93
# Epoch 43:	#####################################################	elapsed: 5.30s, reconstruction error: 3.01
# Epoch 44:	#####################################################	elapsed: 5.12s, reconstruction error: 2.90
# Epoch 45:	#####################################################	elapsed: 5.12s, reconstruction error: 2.91
# Epoch 46:	#####################################################	elapsed: 5.40s, reconstruction error: 2.86
# Epoch 47:	#####################################################	elapsed: 6.90s, reconstruction error: 2.87
# Epoch 48:	#####################################################	elapsed: 5.41s, reconstruction error: 2.87
# Epoch 49:	#####################################################	elapsed: 4.10s, reconstruction error: 2.88
# Training finished!

# %%
draw_layer_samples(dbn, 0, monitoring_set[:8*16])

# %%
draw_layer_samples(dbn, 1, monitoring_set[:8*16])

# %%
draw_layer_samples(dbn, 2, monitoring_set[:8*16])
